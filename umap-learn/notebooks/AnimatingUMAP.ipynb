# %% [markdown]
# # Making Animations of UMAP Hyper-parameters
#
# Sometimes one of the best ways to see the effects of hyperparameters is simply to visualise what happens as they change. We can do that in practice with UMAP by simply creating an animation that transitions between embeddings generated with variations of hyperparameters. To do this we'll make use of matplotlib and its animation capabilities. Jake Vanderplas has [a great tutorial](https://jakevdp.github.io/blog/2012/08/18/matplotlib-animation-tutorial/) if you want to know more about creating animations with matplotlib.

# %% [markdown]
# **Note:**
# This is a self contained example of how to use UMAP and the impact of individual hyper-parameters. To make sure everything works correctly please use `conda`.
# For install and usage details see [here](https://docs.conda.io/en/latest/miniconda.html)
#
# To create animations we need `ffmpeg`. It can be installed with `conda`.
#
# If you already have `ffmpeg` installed on your machine and you know what you are doing you do not need conda. It is only used to install `ffmpeg`.
#
# => Remove the next two cells if you are not using `conda`.

# %%
# !conda --version
# Out:
# conda 4.10.3

# %%
# !conda install -c conda-forge ffmpeg -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/kkepins-macwro_1/opt/anaconda3
#
#   added / updated specs:
#     - ffmpeg
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.11.0               |   py39h6e9494a_2        16.9 MB  conda-forge
#     ffmpeg-4.3.2               |       h4dad6da_0        49.3 MB  conda-forge
#     gettext-0.19.8.1           |    h7937167_1005         3.3 MB  conda-forge
#     gnutls-3.6.13              |       h756fd2b_1         2.0 MB  conda-forge
#     lame-3.100                 |    h35c211d_1001         521 KB  conda-forge
#     nettle-3.6                 |       hedd7734_0         1.2 MB  conda-forge
#     openh264-2.1.1             |       hfd3ada9_0         1.5 MB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     x264-1!161.3030            |       h0d85af4_1         2.5 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        77.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   ffmpeg             conda-forge/osx-64::ffmpeg-4.3.2-h4dad6da_0
#   gettext            conda-forge/osx-64::gettext-0.19.8.1-h7937167_1005
#   gnutls             conda-forge/osx-64::gnutls-3.6.13-h756fd2b_1
#   lame               conda-forge/osx-64::lame-3.100-h35c211d_1001
#   nettle             conda-forge/osx-64::nettle-3.6-hedd7734_0
#   openh264           conda-forge/osx-64::openh264-2.1.1-hfd3ada9_0
#   python_abi         conda-forge/osx-64::python_abi-3.9-2_cp39
#   x264               conda-forge/osx-64::x264-1!161.3030-h0d85af4_1
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.10.3-py39hecd8cb5_0 --> conda-forge::conda-4.11.0-py39h6e9494a_2
#
#
#
# Downloading and Extracting Packages
# gnutls-3.6.13        | 2.0 MB    | ##################################### | 100%
# openh264-2.1.1       | 1.5 MB    | ##################################### | 100%
# lame-3.100           | 521 KB    | ##################################### | 100%
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# conda-4.11.0         | 16.9 MB   | ##################################### | 100%
# ffmpeg-4.3.2         | 49.3 MB   | ##################################### | 100%
# x264-1!161.3030      | 2.5 MB    | ##################################### | 100%
# gettext-0.19.8.1     | 3.3 MB    | ##################################### | 100%
# nettle-3.6           | 1.2 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !python --version
# Out:
# Python 3.9.7

# %% [markdown]
# To start we'll need some basic libraries. First ``numpy`` will be needed for basic array manipulation. Since we will be visualising the results we will need ``matplotlib`` and ``seaborn``. Finally we will need ``umap`` for doing the dimension reduction itself.

# %%
# !pip install numpy matplotlib seaborn umap-learn
# Out:
# Requirement already satisfied: numpy in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (1.20.3)
# Requirement already satisfied: matplotlib in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: seaborn in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: umap-learn in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (0.5.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pandas>=0.23 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: scipy>=1.0 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: numba>=0.49 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from umap-learn) (0.54.1)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from umap-learn) (0.24.2)
# Requirement already satisfied: pynndescent>=0.5 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from umap-learn) (0.5.6)
# Requirement already satisfied: tqdm in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from umap-learn) (4.62.3)
# Requirement already satisfied: six in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: setuptools in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.49->umap-learn) (58.0.4)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.49->umap-learn) (0.37.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: joblib>=0.11 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/kkepins-macwro_1/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->umap-learn) (2.2.0)

# %% [markdown]
# To start let's load everything we'll need

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import animation
from IPython.display import HTML
import seaborn as sns
import itertools
sns.set(style='white', rc={'figure.figsize':(14, 12), 'animation.html': 'html5'})

# %%
# Ignore UserWarnings
import warnings
warnings.simplefilter('ignore', UserWarning)

# %%
from sklearn.datasets import load_digits

# %%
from umap import UMAP

# %% [markdown]
# To try this out we'll needs a reasonably small dataset (so embedding runs don't take *too* long since we'll be doing a lot of them). For ease of reproducibility for everyone else I'll use the digits dataset from sklearn. If you want to try other datasets just drop them in here -- COIL20 might be interesting, or you might have your own data.

# %%
digits = load_digits()
data = digits.data
data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %% [markdown]
# We need to move the points in between the embeddings given by different parameter values. There are potentially fancy ways to do this (Something using rotation and reflection to get an initial alignment might be interesting), but we'll use straighforward linear interpolation between the two embeddings. To do this we'll need a simple function that can turn out intermediate embeddings for the in-between frames of the animation.

# %%
def tween(e1, e2, n_frames=20):
    for i in range(5):
        yield e1
    for i in range(n_frames):
        alpha = i / float(n_frames - 1)
        yield (1 - alpha) * e1 + alpha * e2
    for i in range(5):
        yield(e2)
    return

# %% [markdown]
# Now that we can fill in intermediate frame we just need to generate all the embeddings. We'll create a function that can take an argument and set of parameter values and then generate all the embeddings including the in-between frames.

# %%
def generate_frame_data(data, arg_name='n_neighbors', arg_list=[]):
    result = []
    es = []
    for arg in arg_list:
        kwargs = {arg_name:arg}
        if len(es) > 0:
            es.append(UMAP(init=es[-1], negative_sample_rate=3, **kwargs).fit_transform(data))
        else:
            es.append(UMAP(negative_sample_rate=3, **kwargs).fit_transform(data))
        
    for e1, e2 in zip(es[:-1], es[1:]):
        result.extend(list(tween(e1, e2)))
        
    return result

# %% [markdown]
# Next we just need to create a function to actually generate the animation given a list of embeddings (one for each frame). This is really just a matter of workign through the details of how matplotlib generates animations -- I would refer you again to Jake's tutorial if you are interested in the detailed mechanics of this.

# %%
def create_animation(frame_data, arg_name='n_neighbors', arg_list=[]):
    fig, ax = plt.subplots()
    all_data = np.vstack(frame_data)
    frame_bounds = (all_data[:, 0].min() * 1.1, 
                    all_data[:, 0].max() * 1.1,
                    all_data[:, 1].min() * 1.1, 
                    all_data[:, 1].max() * 1.1)
    ax.set_xlim(frame_bounds[0], frame_bounds[1])
    ax.set_ylim(frame_bounds[2], frame_bounds[3])
    points = ax.scatter(frame_data[0][:, 0], frame_data[0][:, 1], 
                        s=5, c=digits.target, cmap='Spectral', animated=True)
    title = ax.set_title('', fontsize=24)
    ax.set_xticks([])
    ax.set_yticks([])

    cbar = fig.colorbar(
        points,
        cax=make_axes_locatable(ax).append_axes("right", size="5%", pad=0.05),
        orientation="vertical",
        values=np.arange(10),
        boundaries=np.arange(11)-0.5,
        ticks=np.arange(10),
        drawedges=True,
    )
    cbar.ax.yaxis.set_ticklabels(np.arange(10), fontsize=18)

    def init():
        points.set_offsets(frame_data[0])
        arg = arg_list[0]
        arg_str = f'{arg:.3f}' if isinstance(arg, float) else f'{arg}'
        title.set_text(f'UMAP with {arg_name}={arg_str}')
        return (points,)

    def animate(i):
        points.set_offsets(frame_data[i])
        if (i + 15) % 30 == 0:
            arg = arg_list[(i + 15) // 30]
            arg_str = f'{arg:.3f}' if isinstance(arg, float) else f'{arg}'
            title.set_text(f'UMAP with {arg_name}={arg_str}')
        return (points,)

    anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(frame_data), interval=20, blit=True)
    plt.close()
    return anim

# %% [markdown]
# Finally a little bit of glue to make it all go together.

# %%
def animate_param(data, arg_name='n_neighbors', arg_list=[]):
    frame_data = generate_frame_data(data, arg_name, arg_list)
    return create_animation(frame_data, arg_name, arg_list)

# %% [markdown]
# Now we can create an animation. It will be embedded as an HTML5 video into this notebook.

# %%
animate_param(data, 'n_neighbors', [3, 4, 5, 7, 10, 15, 25, 50, 100, 200])
# Out:
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# <video width="1008" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
animate_param(data, 'min_dist', [0.0, 0.01, 0.1, 0.2, 0.4, 0.6, 0.9])
# Out:
# <video width="1008" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
animate_param(data, 'local_connectivity', [0.1, 0.2, 0.5, 1, 2, 5, 10])
# Out:
# <video width="1008" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
animate_param(data, 'set_op_mix_ratio', np.linspace(0.0, 1.0, 10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/r3/hdngxsmd2vq391vqv6kg6f7w0000gq/T/ipykernel_43710/1325023950.py in <module>
# ----> 1 animate_param(data, 'set_op_mix_ratio', np.linspace(0.0, 1.0, 10))
#
# /var/folders/r3/hdngxsmd2vq391vqv6kg6f7w0000gq/T/ipykernel_43710/887738292.py in animate_param(data, arg_name, arg_list)
#       1 def animate_param(data, arg_name='n_neighbors', arg_list=[]):
# ----> 2     frame_data = generate_frame_data(data, arg_name, arg_list)
#       3     return create_animation(frame_data, arg_name, arg_list)
#
# /var/folders/r3/hdngxsmd2vq391vqv6kg6f7w0000gq/T/ipykernel_43710/1411457986.py in generate_frame_data(data, arg_name, arg_list)
#       5         kwargs = {arg_name:arg}
#       6         if len(es) > 0:
# ----> 7             es.append(UMAP(init=es[-1], negative_sample_rate=3, **kwargs).fit_transform(data))
#       8         else:
#       9             es.append(UMAP(negative_sample_rate=3, **kwargs).fit_transform(data))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/umap/umap_.py in fit_transform(self, X, y)
#    2770             Local radii of data points in the embedding (log-transformed).
#    2771         """
# -> 2772         self.fit(X, y)
#    2773         if self.transform_mode == "embedding":
#    2774             if self.output_dens:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/umap/umap_.py in fit(self, X, y)
#    2278
#    2279         if isinstance(self.init, np.ndarray):
# -> 2280             init = check_array(self.init, dtype=np.float32, accept_sparse=False)
#    2281         else:
#    2282             init = self.init
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718
#     719         if force_all_finite:
# --> 720             _assert_all_finite(array,
#     721                                allow_nan=force_all_finite == 'allow-nan')
#     722
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
